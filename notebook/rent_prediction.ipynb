# %%
# import
import pandas as pd

# %%
# load data
dataset = pd.read_csv("rent_apartments.csv")

# %%
# Data Exploration
dataset.head()
# Out:
#                                     address   area  constraction_year  rooms  \
# 0  1071 HN Amsterdam (Cornelis Schuytbuurt)  167.0               1870      3
# 1    1071 HK Amsterdam (Concertgebouwbuurt)  150.0               1890      3
# 2    1071 HK Amsterdam (Concertgebouwbuurt)  150.0               1890      3
# 3      1071 WV Amsterdam (Hondecoeterbuurt)   90.0               1923      3
# 4      1071 WV Amsterdam (Hondecoeterbuurt)  104.0               1923      3
#
#    bedrooms  bathrooms balcony storage parking furnished garage  \
# 0         2          2     yes      no      no       yes     no
# 1         2          2     yes      no     yes       yes     no
# 2         2          2     yes      no     yes       yes     no
# 3         2          1     yes      no      no       yes     no
# 4         2          1      no      no      no        no     no
#
#             garden energy                                         facilities  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   address            1728 non-null   object
#  1   area               1728 non-null   float64
#  2   constraction_year  1728 non-null   int64
#  3   rooms              1728 non-null   int64
#  4   bedrooms           1728 non-null   int64
#  5   bathrooms          1728 non-null   int64
#  6   balcony            1728 non-null   object
#  7   storage            1728 non-null   object
#  8   parking            1728 non-null   object
#  9   furnished          1728 non-null   object
#  10  garage             1728 non-null   object
#  11  garden             1728 non-null   object
#  12  energy             1104 non-null   object
#  13  facilities         1308 non-null   object
#  14  zip                1728 non-null   object
#  15  neighborhood       1728 non-null   object
# ...

# %%
dataset_encoded = pd.get_dummies(dataset, columns=['balcony', 'storage', 'parking', 'furnished', 'garage'], drop_first=True, dtype=int)

# %%
dataset_encoded.head()
# Out:
#                                     address   area  constraction_year  rooms  \
# 0  1071 HN Amsterdam (Cornelis Schuytbuurt)  167.0               1870      3
# 1    1071 HK Amsterdam (Concertgebouwbuurt)  150.0               1890      3
# 2    1071 HK Amsterdam (Concertgebouwbuurt)  150.0               1890      3
# 3      1071 WV Amsterdam (Hondecoeterbuurt)   90.0               1923      3
# 4      1071 WV Amsterdam (Hondecoeterbuurt)  104.0               1923      3
#
#    bedrooms  bathrooms           garden energy  \
# 0         2          2      Not present      D
# 1         2          2      Not present      A
# 2         2          2      Not present      A
# 3         2          1      Not present    NaN
# 4         2          1  Present (47 m²)      D
#
#                                           facilities      zip  \
# 0                                       Roof terrace  1071 HN
# 1  Cable TV, Internet connection, Fireplace, Bath...  1071 HK
# ...

# %%
dataset_encoded.garden.unique()
# Out:
# array(['Not present', 'Present (47 m²)', 'Present (29 m²)',
#        'Present (75 m²)', 'Present (40 m², located on the north)',
#        'Present (50 m²)', 'Present (20 m², located on the south)',
#        'Present (1 m²)', 'Present (15 m²)', 'Present (25 m²)',
#        'Present (12 m²)', 'Present (45 m², located on the south)',
#        'Present (26 m², located on the south-east)',
#        'Present (20 m², located on the north-east)',
#        'Present (42 m², located on the west)', 'Present (46 m²)',
#        'Present (45 m², located on the south-west)',
#        'Present (60 m², located on the south-west)',
#        'Present (50 m², located on the south)',
#        'Present (40 m², located on the north-east)', 'Present (16 m²)',
#        'Present (60 m²)', 'Present (65 m², located on the south)',
#        'Present (90 m²)', 'Present (85 m²)',
#        'Present (85 m², located on the south-west)',
#        'Present (500 m², located on the west)',
# ...

# %%
# Data Preprocessing
import re

# %%
for i in range(len(dataset_encoded)):
    if dataset_encoded.garden[i] == "Not present":
        dataset_encoded.garden[i] = 0
    else:
        dataset_encoded.garden[i] = int(re.findall(r'\d+', dataset_encoded.garden[i])[0])
# Out:
# C:\Users\hgnis\AppData\Local\Temp\ipykernel_20928\4168782201.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_encoded.garden[i] = 0
# C:\Users\hgnis\AppData\Local\Temp\ipykernel_20928\4168782201.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_encoded.garden[i] = 0
# C:\Users\hgnis\AppData\Local\Temp\ipykernel_20928\4168782201.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
dataset_encoded
# Out:
#                                        address   area  constraction_year  \
# 0     1071 HN Amsterdam (Cornelis Schuytbuurt)  167.0               1870
# 1       1071 HK Amsterdam (Concertgebouwbuurt)  150.0               1890
# 2       1071 HK Amsterdam (Concertgebouwbuurt)  150.0               1890
# 3         1071 WV Amsterdam (Hondecoeterbuurt)   90.0               1923
# 4         1071 WV Amsterdam (Hondecoeterbuurt)  104.0               1923
# ...                                        ...    ...                ...
# 1723            1033 DL Amsterdam (Terrasdorp)   75.0               1990
# 1724            1033 DZ Amsterdam (Terrasdorp)   75.0               1990
# 1725          1021 NX Amsterdam (IJplein e.o.)   74.0               1986
# 1726       1021 EC Amsterdam (Vogelbuurt Zuid)  118.0               1920
# 1727       1042 AL Amsterdam (Westhaven Noord)  110.0               2019
#
#       rooms  bedrooms  bathrooms garden energy  \
# ...

# %%
dataset_encoded.garden.unique()
# Out:
# array([0, 47, 29, 75, 40, 50, 20, 1, 15, 25, 12, 45, 26, 42, 46, 60, 16,
#        65, 90, 85, 500, 30, 49, 51, 80, 27, 56, 9, 200, 32, 100, 34],
#       dtype=object)

# %%
X = dataset_encoded[[
    'area', 'rooms', 'bedrooms', 'bathrooms',
    'garden', 'balcony_yes', 'storage_yes', 'parking_yes', 'furnished_yes',
    'garage_yes'
    ]]

# %%
Y = dataset_encoded.rent

# %%
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Train the model
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(train_x, train_y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model.score(test_x, test_y)
# Out:
# 0.6588874773499633

# %%
# Tuning hyperparameters
from sklearn.model_selection import GridSearchCV

# %%
grid_space = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [10, 20, 30, 40, 50]
    }

# %%
grid = GridSearchCV(RandomForestRegressor(random_state=42), grid_space, cv=5, n_jobs=-1, scoring='r2')

# %%
grid.fit(train_x, train_y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, 30, 40, 50],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              scoring='r2')

# %%
print(f"Best score: {grid.best_score_} with params: {grid.best_params_}")
# Out:
# Best score: 0.7184566389841596 with params: {'max_depth': 10, 'n_estimators': 200}

# %%
# Model management
import pickle as pkl

# %%
pkl.dump(model, open("models/model_v1", "wb"))

# %%
model_v1 = pkl.load(open("models/model_v1", "rb"))

# %%
model_v1.predict([[100, 3, 2, 2, 1, 1, 1, 1, 1, 1]])
# Out:
# c:\Users\hgnis\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([2462.925])
